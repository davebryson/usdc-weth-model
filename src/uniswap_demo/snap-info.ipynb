# %%
import pandas as pd

# %%
df = pd.read_json('./data/snapshot_dataframe_300.json')

# %%
df
# Out:
#           ETH         USDC    LIQ_ETH      LIQ_USDC    TICK
# 0    0.000318  3143.789322  59.797774  42439.433965  195788
# 1    0.000318  3143.789322  59.797774  42439.433965  195788
# 2    0.000318  3140.697037  58.664834  46069.026562  195797
# 3    0.000319  3137.558067  58.694688  46046.403518  195807
# 4    0.000319  3134.422234  58.529225  45870.705368  195817
# ..        ...          ...        ...           ...     ...
# 296  0.000368  2719.510664  14.615038   9937.928134  197237
# 297  0.000368  2716.792649  14.622257   9932.899977  197247
# 298  0.000368  2714.077350  14.629570   9927.935017  197257
# 299  0.000369  2711.364764  14.637060   9923.090139  197267
# 300  0.000369  2708.654890  14.644380   9918.130082  197277
#
# [301 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df.plot(x='TICK', y='ETH', ylabel='ETH per 1 USD')
# Out:
# <Axes: xlabel='TICK', ylabel='ETH per 1 USD'>

# %%
df.plot(x='TICK', y='USDC', ylabel='USDC per 1 ETH')
# Out:
# <Axes: xlabel='TICK', ylabel='USDC per 1 ETH'>

# %%
df.plot(x='TICK', y='LIQ_ETH', kind='area')
# Out:
# <Axes: xlabel='TICK'>

# %%
plt.style.use('_mpl-gallery')

# %%
df['LIQ_ETH'].plot()
# Out:
# <Axes: >

# %%
df['LIQ_USDC'].plot()
# Out:
# <Axes: >

# %%
df['ETH'].plot()
# Out:
# <Axes: >

# %%
df['TICK'].plot()
# Out:
# <Axes: >

# %%
df['LIQ_USDC'][:150].plot(kind='area')
# Out:
# <Axes: >

# %%
df[:150].plot()
# Out:
# <Axes: >
